# %% [markdown]
# # Python Chatbot Project
#
# `source`: https://dzone.com/articles/python-chatbot-project-build-your-first-python-pro

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
# from keras.optimizers import SGD
from keras.optimizers.legacy import SGD
import random

import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

# %% [markdown]
# ## Load Data

# %%
intents_file = open('intents.json').read() # read the json file
intents = json.loads(intents_file)

# %% [markdown]
# ## Preprocessing the Data
#
# The model cannot take the raw data. It has to go through a lot of pre-processing for the machine to easily understand. For textual data, there are many preprocessing techniques available. The first technique is tokenizing, in which we break the sentences into words.
#
# By observing the intents file, we can see that each tag contains a list of patterns and responses. We tokenize each pattern and add the words in a list. Also, we create a list of classes and documents to add all the intents associated with patterns.

# %%
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        #add documents in the corpus
        documents.append((word, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# Out:
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Awesome', ',', 'thanks'], 'thanks'), (['Thanks', 'for', 'helping', 'me'], 'thanks'), (['How', 'you', 'could', 'help', 'me', '?'], 'options'), (['What', 'you', 'can', 'do', '?'], 'options'), (['What', 'help', 'you', 'provide', '?'], 'options'), (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'), (['What', 'support', 'is', 'offered'], 'options'), (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'), (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'), (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'], 'adverse_drug'), (['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction'], 'adverse_drug'), (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'], 'adverse_drug'), (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'), (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'), (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'), (['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history'], 'blood_pressure_search'), (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'), (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'), (['Show', 'blood', 'pressure', 'results', 'for', 'patient'], 'blood_pressure_search'), (['Find', 'blood', 'pressure', 'results', 'by', 'ID'], 'blood_pressure_search'), (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'), (['Find', 'pharmacy'], 'pharmacy_search'), (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'), (['Locate', 'pharmacy'], 'pharmacy_search'), (['Search', 'pharmacy'], 'pharmacy_search'), (['Lookup', 'for', 'hospital'], 'hospital_search'), (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'], 'hospital_search'), (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'), (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'), (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]

# %% [markdown]
# Another technique is Lemmatization. We can convert words into the lemma form so that we can reduce all the canonical words. For example, the words play, playing, plays, played, etc. will all be replaced with play. This way, we can reduce the number of total words in our vocabulary. So now we lemmatize each word and remove the duplicate words. In the end, the words contain the vocabulary of our project and classes contain the total entities to classify. To save the python object in a file, we used the pickle.dump() method. These files will be helpful after the training is done and we predict the chats.

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 87 unique lemmatized words ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %% [markdown]
# ## Create Training and Testing Data
#
# To train the model, we will convert each input pattern into numbers. First, we will lemmatize each word of the pattern and create a list of zeroes of the same length as the total number of words. We will set value 1 to only those indexes that contain the word in the patterns. In the same way, we will create the output by setting 1 to the class input the pattern belongs to.

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for word in words:
        bag.append(1) if word in pattern_words else bag.append(0)
        
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
# training = np.array(training)
# # create train and test lists. X - patterns, Y - intents
# train_x = list(training[:,0])
# train_y = list(training[:,1])

train_x = [sequence[0] for sequence in training]
train_y = [sequence[1] for sequence in training]

train_x = np.array(train_x)
train_y = np.array(train_y)

print("Training data created")
# Out:
# Training data created

# %% [markdown]
# ## Training the Model
#
# The architecture of our model will be a neural network consisting of 3 dense layers. The first layer has 128 neurons, the second one has 64 and the last layer will have the same neurons as the number of classes. The dropout layers are introduced to reduce overfitting of the model. We have used the SGD optimizer and fit the data to start the training of the model. After the training of 200 epochs is completed, we then save the trained model using the Keras model.save(“chatbot_model.h5”) function.

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# /Users/elnaramammadova/Documents/01. DOCUMENTS - Elnara’s MacBook Pro/Projects/my_chatbot/mychatbot_env/lib/python3.11/site-packages/keras/src/optimizers/legacy/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 10/10 [==============================] - 0s 773us/step - loss: 2.2639 - accuracy: 0.0426
# Epoch 2/200
# 10/10 [==============================] - 0s 454us/step - loss: 2.2171 - accuracy: 0.1277
# Epoch 3/200
# 10/10 [==============================] - 0s 554us/step - loss: 2.1105 - accuracy: 0.2340
# Epoch 4/200
# 10/10 [==============================] - 0s 495us/step - loss: 2.0238 - accuracy: 0.3404
# Epoch 5/200
# 10/10 [==============================] - 0s 584us/step - loss: 2.0002 - accuracy: 0.3404
# Epoch 6/200
# 10/10 [==============================] - 0s 519us/step - loss: 1.9181 - accuracy: 0.2979
# Epoch 7/200
# 10/10 [==============================] - 0s 501us/step - loss: 1.7531 - accuracy: 0.4255
# Epoch 8/200
# 10/10 [==============================] - 0s 530us/step - loss: 1.5714 - accuracy: 0.5745
# Epoch 9/200
# 10/10 [==============================] - 0s 532us/step - loss: 1.4945 - accuracy: 0.5319
# Epoch 10/200
# 10/10 [==============================] - 0s 473us/step - loss: 1.3866 - accuracy: 0.6170
# Epoch 11/200
# 10/10 [==============================] - 0s 438us/step - loss: 1.2064 - accuracy: 0.6383
# Epoch 12/200
# 10/10 [==============================] - 0s 435us/step - loss: 1.3097 - accuracy: 0.5532
# Epoch 13/200
# 10/10 [==============================] - 0s 520us/step - loss: 1.0601 - accuracy: 0.7234
# Epoch 14/200
# 10/10 [==============================] - 0s 494us/step - loss: 0.9892 - accuracy: 0.8085
# Epoch 15/200
# 10/10 [==============================] - 0s 418us/step - loss: 0.8868 - accuracy: 0.7660
# Epoch 16/200
# 10/10 [==============================] - 0s 548us/step - loss: 0.8030 - accuracy: 0.7234
# Epoch 17/200
# 10/10 [==============================] - 0s 495us/step - loss: 0.8369 - accuracy: 0.7234
# Epoch 18/200
# 10/10 [==============================] - 0s 452us/step - loss: 0.8032 - accuracy: 0.7872
# Epoch 19/200
# 10/10 [==============================] - 0s 488us/step - loss: 0.7749 - accuracy: 0.7872
# Epoch 20/200
# 10/10 [==============================] - 0s 523us/step - loss: 0.6365 - accuracy: 0.8511
# Epoch 21/200
# 10/10 [==============================] - 0s 452us/step - loss: 0.6977 - accuracy: 0.8511
# Epoch 22/200
# 10/10 [==============================] - 0s 463us/step - loss: 0.4595 - accuracy: 0.9362
# Epoch 23/200
# 10/10 [==============================] - 0s 481us/step - loss: 0.6158 - accuracy: 0.8298
# Epoch 24/200
# 10/10 [==============================] - 0s 409us/step - loss: 0.3040 - accuracy: 0.9574
# Epoch 25/200
# 10/10 [==============================] - 0s 449us/step - loss: 0.3636 - accuracy: 0.9362
# Epoch 26/200
# 10/10 [==============================] - 0s 449us/step - loss: 0.3447 - accuracy: 0.9149
# Epoch 27/200
# 10/10 [==============================] - 0s 440us/step - loss: 0.4194 - accuracy: 0.8723
# Epoch 28/200
# 10/10 [==============================] - 0s 425us/step - loss: 0.5321 - accuracy: 0.8085
# Epoch 29/200
# 10/10 [==============================] - 0s 452us/step - loss: 0.1740 - accuracy: 0.9787
# Epoch 30/200
# 10/10 [==============================] - 0s 402us/step - loss: 0.1865 - accuracy: 0.9787
# Epoch 31/200
# 10/10 [==============================] - 0s 470us/step - loss: 0.4028 - accuracy: 0.8723
# Epoch 32/200
# 10/10 [==============================] - 0s 410us/step - loss: 0.4024 - accuracy: 0.8511
# Epoch 33/200
# 10/10 [==============================] - 0s 464us/step - loss: 0.3784 - accuracy: 0.8936
# Epoch 34/200
# 10/10 [==============================] - 0s 451us/step - loss: 0.3156 - accuracy: 0.8936
# Epoch 35/200
# 10/10 [==============================] - 0s 472us/step - loss: 0.2364 - accuracy: 0.9149
# Epoch 36/200
# 10/10 [==============================] - 0s 421us/step - loss: 0.3636 - accuracy: 0.9149
# Epoch 37/200
# 10/10 [==============================] - 0s 477us/step - loss: 0.2001 - accuracy: 0.9574
# Epoch 38/200
# 10/10 [==============================] - 0s 426us/step - loss: 0.2495 - accuracy: 0.9574
# Epoch 39/200
# 10/10 [==============================] - 0s 513us/step - loss: 0.1753 - accuracy: 1.0000
# Epoch 40/200
# 10/10 [==============================] - 0s 442us/step - loss: 0.1563 - accuracy: 0.9574
# Epoch 41/200
# 10/10 [==============================] - 0s 477us/step - loss: 0.2065 - accuracy: 0.9362
# Epoch 42/200
# 10/10 [==============================] - 0s 403us/step - loss: 0.1585 - accuracy: 0.9574
# Epoch 43/200
# 10/10 [==============================] - 0s 501us/step - loss: 0.1991 - accuracy: 0.9574
# Epoch 44/200
# 10/10 [==============================] - 0s 445us/step - loss: 0.1983 - accuracy: 0.9574
# Epoch 45/200
# 10/10 [==============================] - 0s 452us/step - loss: 0.1098 - accuracy: 0.9787
# Epoch 46/200
# 10/10 [==============================] - 0s 444us/step - loss: 0.1591 - accuracy: 0.9574
# Epoch 47/200
# 10/10 [==============================] - 0s 447us/step - loss: 0.0973 - accuracy: 1.0000
# Epoch 48/200
# 10/10 [==============================] - 0s 481us/step - loss: 0.1324 - accuracy: 0.9787
# Epoch 49/200
# 10/10 [==============================] - 0s 469us/step - loss: 0.1606 - accuracy: 0.9787
# Epoch 50/200
# 10/10 [==============================] - 0s 448us/step - loss: 0.0766 - accuracy: 0.9787
# Epoch 51/200
# 10/10 [==============================] - 0s 456us/step - loss: 0.1252 - accuracy: 0.9362
# Epoch 52/200
# 10/10 [==============================] - 0s 449us/step - loss: 0.1642 - accuracy: 0.9362
# Epoch 53/200
# 10/10 [==============================] - 0s 459us/step - loss: 0.1961 - accuracy: 0.9574
# Epoch 54/200
# 10/10 [==============================] - 0s 438us/step - loss: 0.0929 - accuracy: 0.9787
# Epoch 55/200
# 10/10 [==============================] - 0s 422us/step - loss: 0.0789 - accuracy: 0.9787
# Epoch 56/200
# 10/10 [==============================] - 0s 476us/step - loss: 0.1180 - accuracy: 0.9787
# Epoch 57/200
# 10/10 [==============================] - 0s 447us/step - loss: 0.1581 - accuracy: 0.9574
# Epoch 58/200
# 10/10 [==============================] - 0s 415us/step - loss: 0.1298 - accuracy: 0.9574
# Epoch 59/200
# 10/10 [==============================] - 0s 545us/step - loss: 0.0608 - accuracy: 1.0000
# Epoch 60/200
# 10/10 [==============================] - 0s 465us/step - loss: 0.0764 - accuracy: 1.0000
# Epoch 61/200
# 10/10 [==============================] - 0s 418us/step - loss: 0.0873 - accuracy: 0.9574
# Epoch 62/200
# 10/10 [==============================] - 0s 448us/step - loss: 0.0802 - accuracy: 0.9787
# Epoch 63/200
# 10/10 [==============================] - 0s 490us/step - loss: 0.1340 - accuracy: 0.9787
# Epoch 64/200
# 10/10 [==============================] - 0s 403us/step - loss: 0.0664 - accuracy: 0.9787
# Epoch 65/200
# 10/10 [==============================] - 0s 494us/step - loss: 0.0657 - accuracy: 1.0000
# Epoch 66/200
# 10/10 [==============================] - 0s 449us/step - loss: 0.0533 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 453us/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 409us/step - loss: 0.0858 - accuracy: 1.0000
# Epoch 69/200
# 10/10 [==============================] - 0s 469us/step - loss: 0.1426 - accuracy: 0.9787
# Epoch 70/200
# 10/10 [==============================] - 0s 435us/step - loss: 0.0615 - accuracy: 0.9787
# Epoch 71/200
# 10/10 [==============================] - 0s 493us/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 446us/step - loss: 0.0641 - accuracy: 0.9574
# Epoch 73/200
# 10/10 [==============================] - 0s 451us/step - loss: 0.0583 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 412us/step - loss: 0.0493 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0486 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 756us/step - loss: 0.0508 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 511us/step - loss: 0.0725 - accuracy: 0.9787
# Epoch 78/200
# 10/10 [==============================] - 0s 447us/step - loss: 0.0997 - accuracy: 0.9787
# Epoch 79/200
# 10/10 [==============================] - 0s 501us/step - loss: 0.0637 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 532us/step - loss: 0.0927 - accuracy: 0.9574
# Epoch 81/200
# 10/10 [==============================] - 0s 463us/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 426us/step - loss: 0.0964 - accuracy: 0.9574
# Epoch 83/200
# 10/10 [==============================] - 0s 536us/step - loss: 0.0446 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 430us/step - loss: 0.0795 - accuracy: 0.9574
# Epoch 85/200
# 10/10 [==============================] - 0s 436us/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 464us/step - loss: 0.0530 - accuracy: 0.9787
# Epoch 87/200
# 10/10 [==============================] - 0s 518us/step - loss: 0.0671 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 455us/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 427us/step - loss: 0.0331 - accuracy: 0.9787
# Epoch 90/200
# 10/10 [==============================] - 0s 416us/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 505us/step - loss: 0.0880 - accuracy: 0.9787
# Epoch 92/200
# 10/10 [==============================] - 0s 495us/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 443us/step - loss: 0.0711 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 431us/step - loss: 0.0868 - accuracy: 0.9787
# Epoch 95/200
# 10/10 [==============================] - 0s 496us/step - loss: 0.0573 - accuracy: 0.9787
# Epoch 96/200
# 10/10 [==============================] - 0s 456us/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 484us/step - loss: 0.0677 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 459us/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 497us/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 423us/step - loss: 0.0987 - accuracy: 0.9787
# Epoch 101/200
# 10/10 [==============================] - 0s 508us/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 423us/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 463us/step - loss: 0.0642 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 616us/step - loss: 0.0343 - accuracy: 0.9787
# Epoch 105/200
# 10/10 [==============================] - 0s 514us/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 522us/step - loss: 0.0791 - accuracy: 0.9787
# Epoch 107/200
# 10/10 [==============================] - 0s 450us/step - loss: 0.0365 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 509us/step - loss: 0.0601 - accuracy: 0.9787
# Epoch 109/200
# 10/10 [==============================] - 0s 523us/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 498us/step - loss: 0.0629 - accuracy: 0.9787
# Epoch 111/200
# 10/10 [==============================] - 0s 514us/step - loss: 0.0987 - accuracy: 0.9787
# Epoch 112/200
# 10/10 [==============================] - 0s 513us/step - loss: 0.0525 - accuracy: 0.9787
# Epoch 113/200
# 10/10 [==============================] - 0s 458us/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 521us/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 483us/step - loss: 0.0525 - accuracy: 0.9787
# Epoch 116/200
# 10/10 [==============================] - 0s 526us/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 517us/step - loss: 0.0941 - accuracy: 0.9574
# Epoch 118/200
# 10/10 [==============================] - 0s 502us/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 510us/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 469us/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 554us/step - loss: 0.0956 - accuracy: 0.9787
# Epoch 122/200
# 10/10 [==============================] - 0s 499us/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 476us/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 486us/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 482us/step - loss: 0.0230 - accuracy: 0.9787
# Epoch 126/200
# 10/10 [==============================] - 0s 499us/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 551us/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 447us/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 564us/step - loss: 0.0449 - accuracy: 0.9787
# Epoch 130/200
# 10/10 [==============================] - 0s 541us/step - loss: 0.1073 - accuracy: 0.9574
# Epoch 131/200
# 10/10 [==============================] - 0s 557us/step - loss: 0.0522 - accuracy: 0.9787
# Epoch 132/200
# 10/10 [==============================] - 0s 476us/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 503us/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 561us/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 533us/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 452us/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 475us/step - loss: 0.0418 - accuracy: 0.9787
# Epoch 138/200
# 10/10 [==============================] - 0s 507us/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 523us/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 500us/step - loss: 0.0839 - accuracy: 0.9787
# Epoch 141/200
# 10/10 [==============================] - 0s 509us/step - loss: 0.0410 - accuracy: 0.9787
# Epoch 142/200
# 10/10 [==============================] - 0s 455us/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 503us/step - loss: 0.0407 - accuracy: 0.9787
# Epoch 144/200
# 10/10 [==============================] - 0s 528us/step - loss: 0.0205 - accuracy: 0.9787
# Epoch 145/200
# 10/10 [==============================] - 0s 554us/step - loss: 0.0441 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 479us/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 477us/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 529us/step - loss: 0.0346 - accuracy: 0.9787
# Epoch 149/200
# 10/10 [==============================] - 0s 540us/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 484us/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 465us/step - loss: 0.0739 - accuracy: 0.9787
# Epoch 152/200
# 10/10 [==============================] - 0s 513us/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 493us/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 539us/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 487us/step - loss: 0.0485 - accuracy: 0.9787
# Epoch 156/200
# 10/10 [==============================] - 0s 492us/step - loss: 0.1250 - accuracy: 0.9787
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 943us/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 455us/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 477us/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 440us/step - loss: 0.0336 - accuracy: 0.9787
# Epoch 162/200
# 10/10 [==============================] - 0s 468us/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 500us/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 479us/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 520us/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 496us/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 539us/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 486us/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 484us/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 486us/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 529us/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 486us/step - loss: 0.0312 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 474us/step - loss: 0.0508 - accuracy: 0.9787
# Epoch 174/200
# 10/10 [==============================] - 0s 541us/step - loss: 0.0581 - accuracy: 0.9787
# Epoch 175/200
# 10/10 [==============================] - 0s 521us/step - loss: 0.0377 - accuracy: 0.9787
# Epoch 176/200
# 10/10 [==============================] - 0s 461us/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 452us/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 529us/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 711us/step - loss: 0.0941 - accuracy: 0.9574
# Epoch 180/200
# 10/10 [==============================] - 0s 495us/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 446us/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 494us/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 482us/step - loss: 0.0751 - accuracy: 0.9787
# Epoch 184/200
# 10/10 [==============================] - 0s 434us/step - loss: 0.0401 - accuracy: 0.9787
# Epoch 185/200
# 10/10 [==============================] - 0s 511us/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 477us/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 447us/step - loss: 0.0333 - accuracy: 0.9787
# Epoch 188/200
# 10/10 [==============================] - 0s 529us/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 538us/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 453us/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 470us/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 501us/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 537us/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 502us/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 452us/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 454us/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 468us/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 595us/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 521us/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 598us/step - loss: 0.0185 - accuracy: 1.0000
# model created
# /Users/elnaramammadova/Documents/01. DOCUMENTS - Elnara’s MacBook Pro/Projects/my_chatbot/mychatbot_env/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
